# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
cor_tem = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet1')

# %%
cor_tem
# Out:
#     J()     J    PR()       PR     CR()        CR  N%
# 0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
sns.pairplot(cor_tem)

# %%
sns.barplot(x='J',y='N%',data=cor_tem)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('average corrosion density with inhibitor')
# Out:
# Text(0.5, 0, 'average corrosion density with inhibitor')

# %%
cor_tem2 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet2')

# %%
cor_tem2
# Out:
#     J()       J      PR()        PR       CR()        CR  N%
# 0  4.48  2.7000  139.3400   235.210    0.52025  0.313670  40
# 1  4.02  1.0050  157.3100   797.567    0.46755  0.116890  75
# 2  3.09  0.8595    0.8595   231.220  925.71000  0.359100  72
# 3  2.42  0.6500  257.6200  1155.170    0.28064  0.073217  58

# %%
sns.barplot(x='J',y='N%',data=cor_tem2)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('average corrosion density with inhibitor')
# Out:
# Text(0.5, 0, 'average corrosion density with inhibitor')

# %%
sns.barplot(x='CR',y='N%',data=cor_tem)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('average corrosion density with inhibitor')
# Out:
# Text(0.5, 0, 'average corrosion density with inhibitor')

# %%
cor_tem3 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet3')

# %%
cor_tem3
# Out:
#   CYCLE   J()     J    PR()       PR     CR()        CR  N%
# 0     0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1   1st  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2   2nd  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
sns.barplot(x='CYCLE',y='N%',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('average corrosion density with inhibitor')
# Out:
# Text(0.5, 0, 'average corrosion density with inhibitor')

# %%
sns.barplot(x='CYCLE',y='J()',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('average corrosion density with inhibitor')
# Out:
# Text(0.5, 0, 'average corrosion density with inhibitor')

# %%
sns.barplot(x='CYCLE',y='J',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('average corrosion density with inhibitor')
# Out:
# Text(0.5, 0, 'average corrosion density with inhibitor')

# %%
a= cor_tem3.groupby('J()')

# %%
a

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
cor_tem3 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet3')

# %%
cor_tem3
# Out:
#   CYCLE   J()     J    PR()       PR     CR()        CR  N%
# 0     0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1   1st  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2   2nd  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
data = cor_tem3.groupby(['J()','J'])

# %%
print(data)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'cycle':['room temp','first cycle','second cycle'],
     'J()':[4.48,3.33,2.07],
      'J':[3.18,1.10,0.57]})

# %%
df
# Out:
#           cycle   J()     J
# 0     room temp  4.48  3.18
# 1   first cycle  3.33  1.10
# 2  second cycle  2.07  0.57

# %%
df.plot(x='cycle',y=['J()','J'],kind='bar')
# Out:
# <AxesSubplot:xlabel='cycle'>

# %%
import seaborn as sns

# %%
df.plot(x='cycle',y=['J()','J'],kind='bar')
# Out:
# <AxesSubplot:xlabel='cycle'>

# %%
cor_tem3 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet3')

# %%
cor_tem3
# Out:
#   CYCLE   J()     J    PR()       PR     CR()        CR  N%
# 0     0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1   1st  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2   2nd  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
cor_tem3.drop('CYCLE',axis=1,inplace=True)

# %%
cor_tem3
# Out:
#     J()     J    PR()       PR     CR()        CR  N%
# 0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
cor_tem3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
cor_tem3.drop('N%',axis=1,inplace=True)

# %%
cor_tem3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
cor_tem3
# Out:
#     J()     J    PR()       PR     CR()        CR
# 0  4.48  3.18  139.34   215.38  0.52025  0.369100
# 1  3.33  1.10  212.09   723.30  0.38639  0.127380
# 2  2.07  0.57  258.33  1195.66  0.24095  0.065958

# %%
cor_tem4 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet4')

# %%
cor_tem4
# Out:
#    INH%   J()       J      PR()        PR       CR()        CR  N%
# 0   0.0  4.48  2.7000  139.3400   235.210    0.52025  0.313670  40
# 1   1.0  4.02  1.0050  157.3100   797.567    0.46755  0.116890  75
# 2   1.5  3.09  0.8595    0.8595   231.220  925.71000  0.359100  72
# 3   2.0  2.42  0.6500  257.6200  1155.170    0.28064  0.073217  58

# %%
sns.barplot(x='INH%',y='N%',data=cor_tem4)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('average current density with inhibitor')
# Out:
# Text(0.5, 0, 'average current density with inhibitor')

# %%
df2 = pd.DataFrame({
    'INH%':[0,1,1.5,2],
     'J()':[4.48,4.02,3.09,2.42],
      'J':[2.7,1.0050,0.8595,0.6500]})

# %%
df2
# Out:
#    INH%   J()       J
# 0   0.0  4.48  2.7000
# 1   1.0  4.02  1.0050
# 2   1.5  3.09  0.8595
# 3   2.0  2.42  0.6500

# %%
df2.plot(x='INH%',y=['J()','J'],kind='bar')
# Out:
# <AxesSubplot:xlabel='INH%'>

# %%
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,3))
sns.set_style('whitegrid')
sns.countplot(x='J()',data=cor_tem3)
# Out:
# <AxesSubplot:xlabel='J()', ylabel='count'>

# %%
df2.plot(x='INH%',y=['J()','J'],kind='bar')
# Out:
# <AxesSubplot:xlabel='INH%'>

# %%
sns.barplot(x='INH%',y='N%',data=cor_tem4)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('inh%')
# Out:
# Text(0.5, 0, 'inh%')

# %%
df2 = pd.DataFrame({
    'INH%':[0,1,1.5,2],
     'current density without inhibitor':[4.48,4.02,3.09,2.42],
      'current density with inhibitor':[2.7,1.0050,0.8595,0.6500]})

# %%
df2.plot(x='INH%',y=['current density without inhibitor','current density with inhibitor'],kind='bar')
# Out:
# <AxesSubplot:xlabel='INH%'>

# %% [raw]
# # CORRECT CODE START NOW

# %%
cor_tem3
# Out:
#     J()     J    PR()       PR     CR()        CR
# 0  4.48  3.18  139.34   215.38  0.52025  0.369100
# 1  3.33  1.10  212.09   723.30  0.38639  0.127380
# 2  2.07  0.57  258.33  1195.66  0.24095  0.065958

# %%
cor_tem3 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet3')

# %%
cor_tem3
# Out:
#   CYCLE   J()     J    PR()       PR     CR()        CR  N%
# 0     0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1   1st  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2   2nd  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
sns.barplot(x='CYCLE',y='N%',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('NO OF THERMAL CYCLING')
# Out:
# Text(0.5, 0, 'NO OF THERMAL CYCLING')

# %%
df = pd.DataFrame({
    'NO OF THERMAL CYCLING':['room temp','first cycle','second cycle'],
     'current density without inhibitor':[4.48,3.33,2.07],
      'current density with inhibitor':[3.18,1.10,0.57]})

# %%
df.plot(x='NO OF THERMAL CYCLING',y=['current density without inhibitor','current density with inhibitor'],kind='bar')
# Out:
# <AxesSubplot:xlabel='NO OF THERMAL CYCLING'>

# %%
cor_tem3
# Out:
#   CYCLE   J()     J    PR()       PR     CR()        CR  N%
# 0     0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1   1st  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2   2nd  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
sns.set_style('whitegrid')

# %%
sns.barplot(x='CYCLE',y='J()',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('INITIAL CURRENT DENSITY')
plt.xlabel('NO OF THERMAL CYCLING')
# Out:
# Text(0.5, 0, 'NO OF THERMAL CYCLING')

# %%
sns.barplot(x='CYCLE',y='J',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('AVERAGE CURRENT DENSITY WITH INHIBITOR INCREASING')
plt.xlabel('NO OF THERMAL CYCLING')
# Out:
# Text(0.5, 0, 'NO OF THERMAL CYCLING')

# %%
cor_tem4
# Out:
#    INH%   J()       J      PR()        PR       CR()        CR  N%
# 0   0.0  4.48  2.7000  139.3400   235.210    0.52025  0.313670  40
# 1   1.0  4.02  1.0050  157.3100   797.567    0.46755  0.116890  75
# 2   1.5  3.09  0.8595    0.8595   231.220  925.71000  0.359100  72
# 3   2.0  2.42  0.6500  257.6200  1155.170    0.28064  0.073217  58

# %%
sns.barplot(x='INH%',y='N%',data=cor_tem4)
plt.title('GRAPH')
plt.ylabel('INH. EFFICIENCY')
plt.xlabel('INH.%')
# Out:
# Text(0.5, 0, 'INH.%')

# %%
sns.barplot(x='INH%',y='J()',data=cor_tem4)
plt.title('GRAPH')
plt.ylabel('INITIAL CURRENT DENSITY ')
plt.xlabel('INH.%')
# Out:
# Text(0.5, 0, 'INH.%')

# %%
sns.barplot(x='INH%',y='J',data=cor_tem4)
plt.title('GRAPH')
plt.ylabel('AVERAGE CURRENT DENSITY')
plt.xlabel('INH.%')
# Out:
# Text(0.5, 0, 'INH.%')

# %%
df2 = pd.DataFrame({
    'INH%':[0,1,1.5,2],
     'INITIAL CURRENT DENSITY':[4.48,4.02,3.09,2.42],
      'AVERAGE CURRENT DENSITY':[2.7,1.0050,0.8595,0.6500]})

# %%
df2.plot(x='INH%',y=['INITIAL CURRENT DENSITY','AVERAGE CURRENT DENSITY'],kind='bar')
# Out:
# <AxesSubplot:xlabel='INH%'>

# %%
sns.barplot(x='CYCLE',y='N%',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('NO OF THERMAL CYCLING')
# Out:
# Text(0.5, 0, 'NO OF THERMAL CYCLING')

# %%
plt.figure(figsize=(12,3))
sns.set_context('notebook')

# %%
sns.barplot(x='CYCLE',y='N%',data=cor_tem3)
plt.title('GRAPH')
plt.ylabel('inhitor effiency')
plt.xlabel('NO OF THERMAL CYCLING')
plt.figure(figsize=(10,7))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
cor_tem3 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet3')

# %%
cor_tem3
# Out:
#   CYCLE   J()     J    PR()       PR     CR()        CR  N%
# 0     0  4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1   1st  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2   2nd  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
cor_tem3 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet3')

# %%
cor_tem3
# Out:
#       CYCLE   J()     J    PR()       PR     CR()        CR  N%
# 0  CONTROL   4.48  3.18  139.34   215.38  0.52025  0.369100  29
# 1     FIRST  3.33  1.10  212.09   723.30  0.38639  0.127380  67
# 2    SECOND  2.07  0.57  258.33  1195.66  0.24095  0.065958  72

# %%
sns.set_style('whitegrid')

# %%
sns.barplot(x='CYCLE',y='J()',data=cor_tem3)
plt.title('GRAPH1.1')
plt.ylabel('INITIAL CURRENT DENSITY')
plt.xlabel('NO OF THERMAL CYCLE')
plt.figure(figsize=(10,7))

# %%
sns.barplot(x='CYCLE',y='J()',data=cor_tem3)
plt.title('GRAPH1.2')
plt.ylabel('AVERAGE CURRENT DENSITY')
plt.xlabel('NO OF THERMAL CYCLE')
plt.figure(figsize=(10,7))

# %%
sns.barplot(x='CYCLE',y='N%',data=cor_tem3)
plt.title('GRAPH1.4')
plt.ylabel('INHIBITOR EFFICIENCY')
plt.xlabel('NO OF THERMAL CYCLE')
plt.figure(figsize=(10,7))

# %%
df1 = pd.DataFrame({
    'NO OF THERMAL CYCLE':['CONTROL','FIRST','SECOND'],
     'current density without inhibitor':[4.48,3.33,2.07],
      'current density with inhibitor':[3.18,1.10,0.57]})

# %%
df1.plot(x='NO OF THERMAL CYCLE',y=['INITIAL CURRENT DENSITY','AVERAGE CURRENT DENSITY'],kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-2d1e1eba9faf> in <module>
# ----> 1 df1.plot(x='NO OF THERMAL CYCLE',y=['INITIAL CURRENT DENSITY','AVERAGE CURRENT DENSITY'],kind='bar')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     939
#     940                 # don't overwrite
# --> 941                 data = data[y].copy()
#     942
#     943                 if isinstance(data, ABCSeries):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ...

# %%
df1
# Out:
#   NO OF THERMAL CYCLE  current density without inhibitor  \
# 0             CONTROL                               4.48
# 1               FIRST                               3.33
# 2              SECOND                               2.07
#
#    current density with inhibitor
# 0                            3.18
# 1                            1.10
# 2                            0.57

# %%
df1.plot(x='NO OF THERMAL CYCLE',y=['current density without inhibitor','current density with inhibitor'],kind='bar')
plt.title('Graph1.3')
# Out:
# Text(0.5, 1.0, 'Graph1.3')

# %%
cor_tem4 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet4')

# %%
cor_tem4
# Out:
#    INH%   J()       J      PR()        PR       CR()        CR  N%
# 0   0.0  4.48  2.7000  139.3400   235.210    0.52025  0.313670  40
# 1   1.0  4.02  1.0050  157.3100   797.567    0.46755  0.116890  75
# 2   1.5  3.09  0.8595    0.8595   231.220  925.71000  0.359100  72
# 3   2.0  2.42  0.6500  257.6200  1155.170    0.28064  0.073217  58

# %%
sns.barplot(x='INH%',y='J()',data=cor_tem4)
plt.title('GRAPH2.1')
plt.ylabel('INITIAL CURRENT DENSITY')
plt.xlabel('INH%')
plt.figure(figsize=(10,7))

# %%
sns.barplot(x='INH%',y='J',data=cor_tem4)
plt.title('GRAPH2.2')
plt.ylabel('AVERAGE CURRENT DENSITY')
plt.xlabel('INH%')
plt.figure(figsize=(10,7))

# %%
df2 = pd.DataFrame({
    'INH%':[0,1,1.5,2],
     'INITIAL CURRENT DENSITY':[4.48,4.02,3.09,2.42],
      'AVERAGE CURRENT DENSITY':[2.7,1.0050,0.8595,0.6500]})

# %%
df2.plot(x='INH%',y=['INITIAL CURRENT DENSITY','AVERAGE CURRENT DENSITY'],kind='bar')
plt.title('GRAPH2.3')
# Out:
# Text(0.5, 1.0, 'GRAPH2.3')

# %%
sns.barplot(x='INH%',y='N%',data=cor_tem4)
plt.title('GRAPH2.4')
plt.ylabel('AVERAGE CURRENT DENSITY')
plt.xlabel('INH%')
plt.figure(figsize=(10,7))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.barplot(x='INH%',y='N%',data=cor_tem4)
plt.title('GRAPH2.4')
plt.ylabel('INH%')
plt.xlabel('AVERAGE CURRENT DENSITY')
plt.figure(figsize=(10,7))
sns.set_sytle('whitegrid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-190b32a1c7a5> in <module>
# ----> 1 sns.barplot(x='INH%',y='N%',data=cor_tem4)
#       2 plt.title('GRAPH2.4')
#       3 plt.ylabel('INH%')
#       4 plt.xlabel('AVERAGE CURRENT DENSITY')
#       5 plt.figure(figsize=(10,7))
#
# NameError: name 'cor_tem4' is not defined

# %%
cor_tem4 = pd.read_excel('cor_temp.xlsx',sheet_name='Sheet4')

# %%
sns.barplot(x='INH%',y='N%',data=cor_tem4)
plt.title('GRAPH2.4')
plt.ylabel('INH%')
plt.xlabel('AVERAGE CURRENT DENSITY')
plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-190b32a1c7a5> in <module>
#       4 plt.xlabel('AVERAGE CURRENT DENSITY')
#       5 plt.figure(figsize=(10,7))
# ----> 6 sns.set_sytle('whitegrid')
#
# AttributeError: module 'seaborn' has no attribute 'set_sytle'

# %%
sns.set_style('whitegrid')

# %%
sns.barplot(x='INH%',y='N%',data=cor_tem4)
plt.title('GRAPH2.4')
plt.ylabel('INH%')
plt.xlabel('AVERAGE CURRENT DENSITY')
plt.figure(figsize=(10,7))
sns.set_style('whitegrid')
