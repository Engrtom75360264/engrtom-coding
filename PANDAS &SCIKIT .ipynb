# %%
# loading data into pandas

# %%
import pandas as pd
poke = pd.read_csv('pokemon_data.csv')
print(poke.head(5))
print('\n')
print(poke.tail(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
#
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# ...

# %%
# for other file format
# for csv_file
df = pd.read_csv('pokemon_data.csv')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# for xlsx format: use the code below
#df_xlsx = pd.read_excel('pokemon_data.xlsx')
#print(df_xlsx)

#df = pd.read_csv('pokemon_data.txt')

# %% [markdown]
# reading data in pandas

# %%
## read headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
## read each column
print(df['Name'])
print(df['Speed'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object
# 0       45
# 1       60
# 2       80
# 3       80
# 4       65
#       ...
# 795     50
# 796    110
# 797     70
# 798     80
# 799     70
# Name: Speed, Length: 800, dtype: int64

# %%
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
print(df[['Name','Type 1', 'HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
# read each row
print(df.iloc[0])
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
print(df.iloc[1:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
print(df.loc[3])
# Out:
# #                                 3
# Name          VenusaurMega Venusaur
# Type 1                        Grass
# Type 2                       Poison
# HP                               80
# Attack                          100
# Defense                         123
# Sp. Atk                         122
# Sp. Def                         120
# Speed                            80
# Generation                        1
# Legendary                     False
# Name: 3, dtype: object

# %%
print(df.loc[1:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
for index,row in df.iterrows():
    print(index, row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#reading a specific location (R,C)
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
print(df.loc[1,'Name'])
# Out:
# Ivysaur

# %% [markdown]
# Sorting /Describing data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name',ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'],ascending=True)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'],ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Making changes to the data

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# adding new column
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# to remove the column Total
df = df.drop(columns = ['Total'])

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# another way
df['Total'] = df.iloc[:,4:9].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    273
# ...

# %%
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    273  45      49       49
# 1  2                Ivysaur  Grass  Poison    345  60      62       63
# 2  3               Venusaur  Grass  Poison    445  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    545  80     100      123
# 4  4             Charmander   Fire     NaN    244  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    273  45      49       49
# 1  2                Ivysaur  Grass  Poison    345  60      62       63
# 2  3               Venusaur  Grass  Poison    445  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    545  80     100      123
# 4  4             Charmander   Fire     NaN    244  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# SAVING OUR DATA TO DESIRED FORMAT

# %%
# use thes follo codes:
# df.to_csv('modofied.csv',index=False)
# df.to_excel('modofoed.xlsx',index=False)
# df.to_csv('modified.txt', index=False,sep='\t')

# %% [markdown]
# FILTERING DATA

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'poison')]
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    273   45      49       49
# 1      2                Ivysaur  Grass    Poison    345   60      62       63
# 2      3               Venusaur  Grass    Poison    445   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    545   80     100      123
# 48    43                 Oddish  Grass    Poison    290   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    275   56      61       65
# 719  651              Quilladin  Grass       NaN    348   61      78       95
# 720  652             Chesnaught  Grass  Fighting    466   88     107      122
# 740  672                 Skiddo  Grass       NaN    298   66      65       48
# 741  673                 Gogoat  Grass       NaN    463  123     100       62
#
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Fighting')]
# Out:
#        #        Name Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 310  286     Breloom  Grass  Fighting    390  60     130       80       60
# 701  640    Virizion  Grass  Fighting    472  91      90       72       90
# 720  652  Chesnaught  Grass  Fighting    466  88     107      122       74
#
#      Sp. Def  Speed  Generation  Legendary
# 310       60     70           3      False
# 701      129    108           5       True
# 720       75     64           6      False

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'poison') & (df['HP'] > 70)]
#new_df.to_csv('filtered.csv')

# %%
df_df = new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#       #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0     1              Bulbasaur  Grass    Poison    273   45      49       49
# 1     2                Ivysaur  Grass    Poison    345   60      62       63
# 2     3               Venusaur  Grass    Poison    445   80      82       83
# 3     3  VenusaurMega Venusaur  Grass    Poison    545   80     100      123
# 4    43                 Oddish  Grass    Poison    290   45      50       55
# ..  ...                    ...    ...       ...    ...  ...     ...      ...
# 65  650                Chespin  Grass       NaN    275   56      61       65
# 66  651              Quilladin  Grass       NaN    348   61      78       95
# 67  652             Chesnaught  Grass  Fighting    466   88     107      122
# 68  672                 Skiddo  Grass       NaN    298   66      65       48
# 69  673                 Gogoat  Grass       NaN    463  123     100       62
#
# ...

# %%
# string in column contain either fire or glass
import re
df.loc[df['Type 1'].str.contains('Fire|Grass')]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    273   45      49       49
# 1      2                Ivysaur  Grass  Poison    345   60      62       63
# 2      3               Venusaur  Grass  Poison    445   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    545   80     100      123
# 4      4             Charmander   Fire     NaN    244   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    297   62      50       58
# 736  668                 Pyroar   Fire  Normal    401   86      68       72
# 740  672                 Skiddo  Grass     NaN    298   66      65       48
# 741  673                 Gogoat  Grass     NaN    463  123     100       62
# 799  721              Volcanion   Fire   Water    530   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass',flags=re.I)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    273   45      49       49
# 1      2                Ivysaur  Grass  Poison    345   60      62       63
# 2      3               Venusaur  Grass  Poison    445   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    545   80     100      123
# 4      4             Charmander   Fire     NaN    244   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    297   62      50       58
# 736  668                 Pyroar   Fire  Normal    401   86      68       72
# 740  672                 Skiddo  Grass     NaN    298   66      65       48
# 741  673                 Gogoat  Grass     NaN    463  123     100       62
# 799  721              Volcanion   Fire   Water    530   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# make it case insensitive
import re
df.loc[df['Type 1'].str.contains('Fire|Grass',flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    273   45      49       49
# 1      2                Ivysaur  Grass  Poison    345   60      62       63
# 2      3               Venusaur  Grass  Poison    445   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    545   80     100      123
# 4      4             Charmander   Fire     NaN    244   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    297   62      50       58
# 736  668                 Pyroar   Fire  Normal    401   86      68       72
# 740  672                 Skiddo  Grass     NaN    298   66      65       48
# 741  673                 Gogoat  Grass     NaN    463  123     100       62
# 799  721              Volcanion   Fire   Water    530   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# get name that start with mega
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    545   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    534   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    534   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    552   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    350   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    458   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    440   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    560   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    470   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    490  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    495   65     155
# ...

# %%
# get name that start with mega with case insensible
df.loc[df['Name'].str.contains('Mega',regex=True)]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    545   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    534   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    534   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    552   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    350   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    458   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    440   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    560   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    470   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    490  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    495   65     155
# ...

# %%
# meant to say zero or more
df.loc[df['Name'].str.contains('pi[a-z]*',flags=re.I, regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Total   HP  Attack  \
# 13    10                 Caterpie       Bug       NaN    150   45      30
# 20    16                   Pidgey    Normal    Flying    195   40      45
# 21    17                Pidgeotto    Normal    Flying    278   63      60
# 22    18                  Pidgeot    Normal    Flying    378   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying    458   83      80
# 30    25                  Pikachu  Electric       NaN    230   35      55
# 42    37                   Vulpix      Fire       NaN    234   38      41
# 76    70               Weepinbell     Grass    Poison    335   65      90
# 84    78                 Rapidash      Fire       NaN    395   65     100
# 136  127                   Pinsir       Bug       NaN    415   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying    495   65     155
# 181  167                 Spinarak       Bug    Poison    220   40      60
# ...

# %%
# meant to say zero or more
# show pi letter
df.loc[df['Name'].str.contains('^pi[a-z]*',flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    195   40      45
# 21    17            Pidgeotto    Normal    Flying    278   63      60
# 22    18              Pidgeot    Normal    Flying    378   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    458   83      80
# 30    25              Pikachu  Electric       NaN    230   35      55
# 136  127               Pinsir       Bug       NaN    415   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    495   65     155
# 186  172                Pichu  Electric       NaN    145   20      40
# 219  204               Pineco       Bug       NaN    275   50      65
# 239  221            Piloswine       Ice    Ground    400  100     100
# 438  393               Piplup     Water       NaN    274   53      51
# 558  499              Pignite      Fire  Fighting    363   90      93
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander     Fire     NaN    244  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    590  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    530  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion     Fire   Water    530  80     110      120
#
# ...

# %% [markdown]
# conditional changes

# %%
# change where u see instance [Fire] in row Type 1 to Flamer
df.loc[df['Type 1'] == 'Fire','Type 1'] = 'Flamer'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander   Flamer     NaN    244  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    590  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    530  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion   Flamer   Water    530  80     110      120
#
# ...

# %%
# change where u see instance [Flamer] in row Type 1 to Fire
df.loc[df['Type 1'] == 'Flamer','Type 1'] = 'Fire'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander     Fire     NaN    244  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    590  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    530  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion     Fire   Water    530  80     110      120
#
# ...

# %%
# when fire instance in Type1 is Fire then put Legendary value to be True
df.loc[df['Type 1'] == 'Fire','Legendary'] = True
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander     Fire     NaN    244  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    590  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    530  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion     Fire   Water    530  80     110      120
#
# ...

# %%
# change where total value is more than 500 in Generation, Legendary to TEST VALUE
df.loc[df['Total'] > 500,['Generation','Legendary']] = 'TEST VALUE'
df
# Out:
# C:\Users\Engr. Tom\AppData\Local\Temp\ipykernel_1176\1793911784.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'TEST VALUE' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] > 500,['Generation','Legendary']] = 'TEST VALUE'
# C:\Users\Engr. Tom\AppData\Local\Temp\ipykernel_1176\1793911784.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'TEST VALUE' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] > 500,['Generation','Legendary']] = 'TEST VALUE'
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# ...

# %%
# change where total value is more than 500 in Generation, Legendary to TEST VALUE
df.loc[df['Total'] > 500,['Generation','Legendary']] = ['test1','test2']
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    273  45      49       49
# 1      2                Ivysaur    Grass  Poison    345  60      62       63
# 2      3               Venusaur    Grass  Poison    445  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    545  80     100      123
# 4      4             Charmander     Fire     NaN    244  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    550  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    590  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    530  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    600  80     160       60
# 799  721              Volcanion     Fire   Water    530  80     110      120
#
# ...

# %% [markdown]
# Aggregate Statistics(Groupby)

# %%
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# adding new column
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
#rearranging the order of colums
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# first way of applying groupby()
numeric_cols = df.select_dtypes(include='number').columns
df.groupby(['Type 1'])[numeric_cols].mean()
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
# second way
df.groupby(['Type 1']).mean(numeric_only=True)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# ...

# %%
df.groupby(['Type 1']).mean(numeric_only=True).sort_values('Defense',ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# ...

# %%
df.groupby(['Type 1']).sum(numeric_only=True).sort_values('Defense',ascending=False)
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     33946  48211  8071    8305     8170     8379     7898   7388
# Normal    31279  39365  7573    7200     5865     5470     6245   7012
# Grass     24141  29480  4709    5125     4956     5425     4930   4335
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Rock      17280  19965  2876    4086     4435     2787     3321   2460
# Psychic   21706  27129  4026    4073     3858     5609     4918   4645
# Fire      17025  23820  3635    4408     3524     4627     3755   3871
# Steel     11957  13168  1761    2503     3412     1823     2177   1492
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Ghost     15568  14066  2062    2361     2598     2539     2447   2059
# ...

# %%
# using count()
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
df = pd.read_csv('pokemon_data.csv')
df['count'] = 1
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  count
# 0         65       65     45           1      False      1
# ...

# %%
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
# groupby multiple parameter
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# Working with large data

# %%
for df in pd.read_csv('pokemon_data.csv', chunksize=5):
    print('CHUNK DF')
    print(df)
# Out:
# CHUNK DF
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# CHUNK DF
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# ...

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('pokemon_data.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])

# %%
new_df
# Out:
#          # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0  1      1       1       1       1     1
# Grass    4    4    NaN      4  4      4       4       4       4     4
# Fire     4    4    NaN      3  4      4       4       4       4     4
# Water    1    1    NaN      0  1      1       1       1       1     1
# Bug      2    2    NaN      0  2      2       2       2       2     2
# ...     ..  ...    ...    ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0  1      1       1       1       1     1
# Flying   2    2    NaN      2  2      2       2       2       2     2
# Fire     1    1    NaN      1  1      1       1       1       1     1
# Psychic  2    2    NaN      2  2      2       2       2       2     2
# Rock     2    2    NaN      2  2      2       2       2       2     2
#
#         Generation Legendary
# Fire             1         1
# Grass            4         4
# Fire             4         4
# ...

# %%
# sci kit learn tutorial

# %%
import json
file_name = 'Books_small_10000.json'
with open (file_name) as f:
    for line in f:
        review = json.loads(line)
        print(review['reviewText'])
        print(review['overall'])
        break
# Out:
# I bought both boxed sets, books 1-5.  Really a great series!  Start book 1 three weeks ago and just finished book 5.  Sloane Monroe is a great character and being able to follow her through both private life and her PI life gets a reader very involved!  Although clues may be right in front of the reader, there are twists and turns that keep one guessing until the last page!  These are books you won't be disappointed with.
# 5.0

# %%
import json
file_name = 'Books_small_10000.json'
with open (file_name) as f:
    for line in f:
        review = json.loads(line)
        print(review['reviewText'])
        print(review['overall'])

reviews[5]
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The book was a long read but it held my attention well. The author definitely was able to convey Theo's (the main character's) pain. It takes you through all the anguish he felt as he tried to go on with his life. The painting of the Gold Finch was the catalyst throughout the whole story  to bring him to places he never would of went giving the book high adventure and soul searching.
# 4.0
# Well written,  imaginative, engrossing. I couldn't put it down once I started and it has stayed with me. Frankly, I didn't want it to end.
# 4.0
# ...

# %%
class Review:
    def __init__(self,text, score):
        self.text = text
        self.score = score

# %%
import json
file_name = 'Books_small_10000.json'
with open (file_name) as f:
    for line in f:
        review = json.loads(line)
        print(review['reviewText'])
        print(review['overall'])

reviews[5].score

# %%
import json

# Define the Review class
class Review:
    def __init__(self, text, rating):
        self.text = text
        self.rating = rating

# Load the reviews from the file
file_name = 'Books_small_10000.json'
reviews = []
with open(file_name) as f:
    for line in f:
        review = json.loads(line)
        reviews.append(Review(review['reviewText'], review['overall']))

# Access the text of the 6th review (index 5)
print(reviews[5].text)
# Out:
# I hoped for Mia to have some peace in this book, but her story is so real and raw.  Broken World was so touching and emotional because you go from Mia's trauma to her trying to cope.  I love the way the story displays how there is no "just bouncing back" from being sexually assaulted.  Mia showed us how those demons come for you every day and how sometimes they best you. I was so in the moment with Broken World and hurt with Mia because she was surrounded by people but so alone and I understood her feelings.  I found myself wishing I could give her some of my courage and strength or even just to be there for her.  Thank you Lizzy for putting a great character's voice on a strong subject and making it so that other peoples story may be heard through Mia's.

# %%
class Review:
    def __init__(self,text, score):
        self.text = text
        self.score = score

# %%
# Load the reviews from the file
file_name = 'Books_small_10000.json'
reviews = []
with open(file_name) as f:
    for line in f:
        review = json.loads(line)
        reviews.append(Review(review['reviewText'], review['overall']))

# Access the text of the 6th review (index 5)
print(reviews[5].score)
# Out:
# 5.0

# %%
class Sentiment:
    NEGATIVE ='NEGATIVE'
    NEUTRAL = 'NEUTRAL'
    POSITIVE = 'POSITIVE'

class Review:
    def __init__(self,text, score):
        self.text = text
        self.score = score
        self.sentiment = self.get_sentiment()
    def get_sentiment(self):
        if self.score <= 2:
            return 'NEGATIVE'
        elif self.score == 3:
            return 'NEUTRAL'
        else: # score of 4 0r 5
            return 'POSITIVE'

# %%
import json

file_name = 'Books_small_10000.json'

reviews = []
with open(file_name) as f:
    for line in f:
        review = json.loads(line)
        reviews.append(Review(review['reviewText'], review['overall']))

reviews[5].text
# Out:
# 'I hoped for Mia to have some peace in this book, but her story is so real and raw.  Broken World was so touching and emotional because you go from Mia\'s trauma to her trying to cope.  I love the way the story displays how there is no "just bouncing back" from being sexually assaulted.  Mia showed us how those demons come for you every day and how sometimes they best you. I was so in the moment with Broken World and hurt with Mia because she was surrounded by people but so alone and I understood her feelings.  I found myself wishing I could give her some of my courage and strength or even just to be there for her.  Thank you Lizzy for putting a great character\'s voice on a strong subject and making it so that other peoples story may be heard through Mia\'s.'

# %%
import json

file_name = 'Books_small_10000.json'

reviews = []
with open(file_name) as f:
    for line in f:
        review = json.loads(line)
        reviews.append(Review(review['reviewText'], review['overall']))

reviews[5].sentiment
# Out:
# 'POSITIVE'

# %%
class Sentiment:
    NEGATIVE ='NEGATIVE'
    NEUTRAL = 'NEUTRAL'
    POSITIVE = 'POSITIVE'

class Review:
    def __init__(self,text, score):
        self.text = text
        self.score = score
        self.sentiment = self.get_sentiment()
    def get_sentiment(self):
        if self.score <= 2:
            return Sentiment.NEGATIVE
        elif self.score == 3:
            return Sentiment.NEUTRAL
        else: # score of 4 0r 5
            return Sentiment.POSITIVE

# %%
import json

file_name = 'Books_small_10000.json'

reviews = []
with open(file_name) as f:
    for line in f:
        review = json.loads(line)
        reviews.append(Review(review['reviewText'], review['overall']))

reviews[5].sentiment
# Out:
# 'POSITIVE'

# %% [markdown]
# data preparation

# %%
from sklearn.model_selection import train_test_split
training, test = train_test_split(reviews, test_size=0.33, random_state=42)

# %%
len(training)
# Out:
# 6700

# %%
len(test)
# Out:
# 3300

# %%
print(training[0].text)
# Out:
# Olivia Hampton arrives at the Dunraven family home as cataloger of their extensive library. What she doesn't expect is a broken carriage wheel on the way. Nor a young girl whose mind is clearly gone, an old man in need of care himself (and doesn&#8217;t quite seem all there in Olivia&#8217;s opinion). Furthermore, Marion Dunraven, the only sane one of the bunch and the one Olivia is inexplicable drawn to, seems captive to everyone in the dusty old house. More importantly, she doesn't expect to fall in love with Dunraven's daughter Marion.Can Olivia truly believe the stories of sadness and death that surround the house, or are they all just local neighborhood rumor?Was that carriage trouble just a coincidence or a supernatural sign to stay away? If she remains, will the Castle&#8217;s dark shadows take Olivia down with them or will she and Marion long enough to declare their love?Patty G. Henderson has created an atmospheric and intriguing story in her Gothic tale. I found this to be 
# ...

# %%
print(training[0].sentiment)
# Out:
# POSITIVE

# %%
train_x = [x.text for x in training]
train_y = [x.sentiment for x in training]

test_x = [x.text for x in test]
text_y = [x.sentiment for x in test]

# %% [markdown]
# Bag of words vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
train_x_vectors = vectorizer.fit_transform(train_x)

test_x_vectors = vectorizer.transform(test_x)
print(train_x[0])
print(train_x_vectors[0])
# Out:
# Olivia Hampton arrives at the Dunraven family home as cataloger of their extensive library. What she doesn't expect is a broken carriage wheel on the way. Nor a young girl whose mind is clearly gone, an old man in need of care himself (and doesn&#8217;t quite seem all there in Olivia&#8217;s opinion). Furthermore, Marion Dunraven, the only sane one of the bunch and the one Olivia is inexplicable drawn to, seems captive to everyone in the dusty old house. More importantly, she doesn't expect to fall in love with Dunraven's daughter Marion.Can Olivia truly believe the stories of sadness and death that surround the house, or are they all just local neighborhood rumor?Was that carriage trouble just a coincidence or a supernatural sign to stay away? If she remains, will the Castle&#8217;s dark shadows take Olivia down with them or will she and Marion long enough to declare their love?Patty G. Henderson has created an atmospheric and intriguing story in her Gothic tale. I found this to be 
# ...

# %% [markdown]
# classification

# %% [markdown]
# linear SVM

# %%
from sklearn import svm

clf_svm = svm.SVC(kernel='linear')
clf_svm.fit(train_x_vectors, train_y)
# Out:
# SVC(kernel='linear')

# %%
clf_svm.predict(test_x_vectors)
# Out:
# array(['POSITIVE', 'POSITIVE', 'POSITIVE', ..., 'POSITIVE', 'POSITIVE',
#        'POSITIVE'], dtype='<U8')

# %%
test_x[0]
predictions = clf_svm.predict(test_x_vectors[0].reshape(1, -1))

# %%
print(predictions)
# Out:
# ['POSITIVE']

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dec = DecisionTreeClassifier()
clf_dec.fit(train_x_vectors, train_y)
# Out:
# DecisionTreeClassifier()

# %%
clf_dec.predict(test_x_vectors[0])
# Out:
# array(['POSITIVE'], dtype='<U8')

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# Convert the sparse matrices to dense arrays
train_x_dense = train_x_vectors.toarray()
test_x_dense = test_x_vectors.toarray()

# Initialize and fit the Gaussian Naive Bayes model
clf_gnb = GaussianNB()
clf_gnb.fit(train_x_dense, train_y)

# Make predictions on the test data
prediction = clf_gnb.predict(test_x_dense[0].reshape(1, -1))
print(prediction)
# Out:
# ['POSITIVE']

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf_log = LogisticRegression()
clf_log.fit(train_x_vectors, train_y)

clf_log.predict(test_x_vectors[0])
# Out:
# C:\Users\Engr. Tom\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array(['POSITIVE'], dtype='<U8')

# %% [markdown]
# EVALUATION

# %%
# Mean Accuracy
print(clf_svm.score(test_x_vectors, text_y))
print(clf_dec.score(test_x_vectors, text_y))
print(clf_gnb.score(test_x_dense, text_y))
print(clf_log.score(test_x_vectors, text_y))
# Out:
# 0.8124242424242424
# 0.7684848484848484
# 0.6587878787878788
# 0.8409090909090909

# %%
# F1 Scores
from sklearn.metrics import f1_score

f1_score(text_y, clf_svm.predict(test_x_vectors), average=None, labels=[Sentiment.POSITIVE, Sentiment.NEGATIVE])
f1_score(text_y, clf_log.predict(test_x_vectors), average=None, labels=[Sentiment.POSITIVE, Sentiment.NEUTRAL, Sentiment.NEGATIVE])
# Out:
# array([0.92139968, 0.29250457, 0.40983607])

# %%
train_x[0]
# Out:
# "Olivia Hampton arrives at the Dunraven family home as cataloger of their extensive library. What she doesn't expect is a broken carriage wheel on the way. Nor a young girl whose mind is clearly gone, an old man in need of care himself (and doesn&#8217;t quite seem all there in Olivia&#8217;s opinion). Furthermore, Marion Dunraven, the only sane one of the bunch and the one Olivia is inexplicable drawn to, seems captive to everyone in the dusty old house. More importantly, she doesn't expect to fall in love with Dunraven's daughter Marion.Can Olivia truly believe the stories of sadness and death that surround the house, or are they all just local neighborhood rumor?Was that carriage trouble just a coincidence or a supernatural sign to stay away? If she remains, will the Castle&#8217;s dark shadows take Olivia down with them or will she and Marion long enough to declare their love?Patty G. Henderson has created an atmospheric and intriguing story in her Gothic tale. I found this to be
# ...

# %%
train_y[0:5]
# Out:
# ['POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE', 'POSITIVE']

# %%
train_y.count(Sentiment.POSITIVE)
# Out:
# 5611

# %%
train_y.count(Sentiment.NEGATIVE)
# Out:
# 436

# %%
import random

class Sentiment:
    NEGATIVE ='NEGATIVE'
    NEUTRAL = 'NEUTRAL'
    POSITIVE = 'POSITIVE'

class Review:
    def __init__(self,text, score):
        self.text = text
        self.score = score
        self.sentiment = self.get_sentiment()
    def get_sentiment(self):
        if self.score <= 2:
            return Sentiment.NEGATIVE
        elif self.score == 3:
            return Sentiment.NEUTRAL
        else: # score of 4 0r 5
            return Sentiment.POSITIVE

class ReviewContainer:
    def __init__(self,reviews):
        self.reviews = reviews

    def get_text(self):
        return [x.text for x in self.reviews]

    def get_sentiment(self):
        return [x.sentiment for x in self.reviews]
        
    def evenly_distribute(self):
        negative = list(filter(lambda x: x.sentiment == Sentiment.NEGATIVE, self.reviews))
        positive = list(filter(lambda x: x.sentiment == Sentiment.POSITIVE, self.reviews))
        positive_shrunk = positive[:len(negative)]
        self.reviews = negative + positive_shrunk
        random.shuffle(self.reviews)

# %% [markdown]
# load the dataset

# %%
import json

file_name = 'Books_small_10000.json'
   
reviews = []
with open(file_name) as f:
    for line in f:
        review = json.loads(line)
        reviews.append(Review(review['reviewText'], review['overall']))

reviews[5].sentiment
# Out:
# 'POSITIVE'

# %% [markdown]
# prep Data

# %%
from sklearn.model_selection import train_test_split

training, test = train_test_split(reviews, test_size=0.33, random_state=42)

train_container = ReviewContainer(training)
test_container = ReviewContainer(test)

# %%
train_container.evenly_distribute()
train_x = train_container.get_text()
train_y = train_container.get_sentiment()

test_container.evenly_distribute()
test_x = test_container.get_text()
text_y = test_container.get_sentiment()

print(train_y.count(Sentiment.POSITIVE))
print(train_y.count(Sentiment.NEGATIVE))
# Out:
# 436
# 436

# %% [markdown]
# Bag of words Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
train_x_vectors = vectorizer.fit_transform(train_x)

test_x_vectors = vectorizer.transform(test_x)
print(train_x[0])
print(train_x_vectors[0])
# Out:
# I have read all of Ms. Higgins' work and I am always sent into gales of laughter. This book was true to form. This time the scene that sent me over the edge was when Colleen made Lucas dinner. Hilarious. I have truly enjoyed the Blue Heron series and anxiously await future books for Jack and Connor.
#   (0, 3669)	2
#   (0, 6392)	1
#   (0, 347)	1
#   (0, 5478)	2
#   (0, 5222)	1
#   (0, 3760)	1
#   (0, 8797)	1
#   (0, 423)	3
#   (0, 387)	1
#   (0, 386)	1
#   (0, 6989)	2
#   (0, 4212)	1
#   (0, 3313)	1
#   (0, 4571)	1
#   (0, 7976)	2
#   (0, 991)	1
#   (0, 8608)	2
#   (0, 8204)	1
#   (0, 8052)	1
#   (0, 3202)	1
#   (0, 8036)	1
#   (0, 7929)	3
#   (0, 6896)	1
#   (0, 7925)	1
#   (0, 4982)	1
#   (0, 5606)	1
#   (0, 2554)	1
#   (0, 8685)	1
#   (0, 1541)	1
#   (0, 4840)	1
#   (0, 4802)	1
#   (0, 2263)	1
#   (0, 3775)	1
#   (0, 8205)	1
#   (0, 2688)	1
#   (0, 961)	1
#   (0, 3748)	1
#   (0, 7002)	1
#   (0, 464)	1
#   (0, 679)	1
#   (0, 3307)	1
#   (0, 996)	1
#   (0, 3177)	1
#   (0, 4315)	1
# ...

# %% [markdown]
# classification

# %% [markdown]
# Linear SVM

# %%
from sklearn import svm

clf_svm = svm.SVC(kernel='linear')

clf_svm.fit(train_x_vectors, train_y)

test_x[0]

clf_svm.predict(test_x_vectors[0])
# Out:
# array(['NEGATIVE'], dtype='<U8')

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dec = DecisionTreeClassifier()
clf_dec.fit(train_x_vectors, train_y)
clf_dec.predict(test_x_vectors[0])
# Out:
# array(['NEGATIVE'], dtype='<U8')

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# Convert the sparse matrices to dense arrays
train_x_dense = train_x_vectors.toarray()
test_x_dense = test_x_vectors.toarray()

# Initialize and fit the Gaussian Naive Bayes model
clf_gnb = GaussianNB()
clf_gnb.fit(train_x_dense, train_y)

# Make predictions on the test data
prediction = clf_gnb.predict(test_x_dense[0].reshape(1, -1))
print(prediction)
# Out:
# ['NEGATIVE']

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf_log = LogisticRegression()
clf_log.fit(train_x_vectors, train_y)

clf_log.predict(test_x_vectors[0])
# Out:
# array(['NEGATIVE'], dtype='<U8')

# %% [markdown]
# Evaluation

# %%
# Mean Accuracy
print(clf_svm.score(test_x_vectors, text_y))
print(clf_dec.score(test_x_vectors, text_y))
print(clf_gnb.score(test_x_dense, text_y))
print(clf_log.score(test_x_vectors, text_y))
# Out:
# 0.7980769230769231
# 0.6370192307692307
# 0.6346153846153846
# 0.8173076923076923

# %%
# F1 Scores
# F1 Scores
from sklearn.metrics import f1_score

f1_score(text_y, clf_svm.predict(test_x_vectors), average=None, labels=[Sentiment.POSITIVE, Sentiment.NEGATIVE])
f1_score(text_y, clf_log.predict(test_x_vectors), average=None, labels=[Sentiment.POSITIVE, Sentiment.NEUTRAL, Sentiment.NEGATIVE])
# Out:
# C:\Users\Engr. Tom\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# array([0.82325581, 0.        , 0.81094527])

# %%
text_y.count(Sentiment.NEGATIVE)
# Out:
# 208

# %%
text_y.count(Sentiment.POSITIVE)
# Out:
# 208

# %% [markdown]
# rought_check

# %%
new_set = [ 'I thoroughly enjoyed this , 5 stars', 'bad book do not buy', 'horrible waste of time']
new_test = vectorizer.transform(new_set)

clf_svm.predict(new_test)
# Out:
# array(['POSITIVE', 'NEGATIVE', 'NEGATIVE'], dtype='<U8')

# %%
new_set2 = ['great and amazing',' average i can manage it ,u can buy if u have much money','dangerous']
new_test2 = vectorizer.transform(new_set2)

clf_svm.predict(new_test2)
# Out:
# array(['POSITIVE', 'NEGATIVE', 'NEGATIVE'], dtype='<U8')

# %% [markdown]
# To improve the accuracy then word on the bag of words vectoriztion, by introducing TfidfVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# this book is great
# this book was so bad

vectorizer = TfidfVectorizer()
train_x_vectors = vectorizer.fit_transform(train_x)

test_x_vectors = vectorizer.transform(test_x)
print(train_x[0])
print(train_x_vectors[0])
# Out:
# I have read all of Ms. Higgins' work and I am always sent into gales of laughter. This book was true to form. This time the scene that sent me over the edge was when Colleen made Lucas dinner. Hilarious. I have truly enjoyed the Blue Heron series and anxiously await future books for Jack and Connor.
#   (0, 1671)	0.20240959683644932
#   (0, 4315)	0.1767100748059436
#   (0, 3177)	0.05237978740332974
#   (0, 996)	0.08584605736759576
#   (0, 3307)	0.14062861707655452
#   (0, 679)	0.20240959683644932
#   (0, 464)	0.21470782154064627
#   (0, 7002)	0.08928344719341759
#   (0, 3748)	0.21470782154064627
#   (0, 961)	0.20240959683644932
#   (0, 2688)	0.1032013790892714
#   (0, 8205)	0.13466216681513937
#   (0, 3775)	0.19368386754524414
#   (0, 2263)	0.19368386754524414
#   (0, 4802)	0.20240959683644932
#   (0, 4840)	0.1110442265923126
#   (0, 1541)	0.19368386754524414
#   (0, 8685)	0.08880199019297907
#   (0, 2554)	0.15793390113909128
#   (0, 5606)	0.10911779169154767
# ...

# %% [markdown]
# retrain the model 1

# %%
from sklearn import svm

clf_svm = svm.SVC(kernel='linear')

clf_svm.fit(train_x_vectors, train_y)

test_x[0]

clf_svm.predict(test_x_vectors[0])
# Out:
# array(['NEGATIVE'], dtype='<U8')

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dec = DecisionTreeClassifier()
clf_dec.fit(train_x_vectors, train_y)
clf_dec.predict(test_x_vectors[0])
# Out:
# array(['NEGATIVE'], dtype='<U8')

# %%
from sklearn.naive_bayes import GaussianNB

# Convert the sparse matrices to dense arrays
train_x_dense = train_x_vectors.toarray()
test_x_dense = test_x_vectors.toarray()

# Initialize and fit the Gaussian Naive Bayes model
clf_gnb = GaussianNB()
clf_gnb.fit(train_x_dense, train_y)

# Make predictions on the test data
prediction = clf_gnb.predict(test_x_dense[0].reshape(1, -1))
print(prediction)
# Out:
# ['NEGATIVE']

# %%
from sklearn.linear_model import LogisticRegression

clf_log = LogisticRegression()
clf_log.fit(train_x_vectors, train_y)

clf_log.predict(test_x_vectors[0])
# Out:
# array(['NEGATIVE'], dtype='<U8')

# %% [markdown]
# evaluation

# %%
# Mean Accuracy
print(clf_svm.score(test_x_vectors, text_y))
print(clf_dec.score(test_x_vectors, text_y))
print(clf_gnb.score(test_x_dense, text_y))
print(clf_log.score(test_x_vectors, text_y))
# Out:
# 0.8076923076923077
# 0.6418269230769231
# 0.6610576923076923
# 0.8028846153846154

# %%
# F1 Scores
# F1 Scores
from sklearn.metrics import f1_score

f1_score(text_y, clf_svm.predict(test_x_vectors), average=None, labels=[Sentiment.POSITIVE, Sentiment.NEGATIVE])
f1_score(text_y, clf_log.predict(test_x_vectors), average=None, labels=[Sentiment.POSITIVE, Sentiment.NEUTRAL, Sentiment.NEGATIVE])
# Out:
# C:\Users\Engr. Tom\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# array([0.80097087, 0.        , 0.8047619 ])

# %% [markdown]
# to boast accuracy we also do tuning our model(with Grid Search)

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'kernel':('linear','rbf'),'C':(1,4,8,16,32)}

svc = svm.SVC()
clf = GridSearchCV(svc, parameters, cv=5)
clf.fit(train_x_vectors, train_y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': (1, 4, 8, 16, 32), 'kernel': ('linear', 'rbf')})

# %%
# Mean Accuracy
print(clf_svm.score(test_x_vectors, text_y))
# Out:
# 0.8076923076923077

# %% [markdown]
# saving Model

# %%
import os
import pickle

# Ensure the directory exists
os.makedirs('./models', exist_ok=True)

# Now save the classifier
with open('./models/sentiment_classifier.pkl', 'wb') as f:
    pickle.dump(clf, f)

# %% [markdown]
# LOAD Model

# %%
with open('./models/sentiment_classifier.pkl', 'rb') as f:
    loaded_clf = pickle.load(f)

# %%
print(test_x[0])

loaded_clf.predict((test_x_vectors[0]))
# Out:
# well dione what an family  I do not know anyone rich 9or royal.  gives me asn idea about.  got ingo I did not know.
# array(['NEGATIVE'], dtype='<U8')

# %% [markdown]
# import libraries

# %%
import numpy as np
import random
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import f1_score

import json

# %%
class Category:
    ELECTRONICS = "ELECTRONICS"
    BOOKS = "BOOKS"
    CLOTHING = "CLOTHING"
    GROCERY = "GROCERY"
    PATIO = "PATIO"
    
class Sentiment:
    POSITIVE = "POSITIVE"
    NEGATIVE = "NEGATIVE"
    NEUTRAL = "NEUTRAL"

class Review:
    def __init__(self, text, score, category):
        self.text = text
        self.category = category
        
        # Try to convert score to an integer
        try:
            self.score = int(score)
            self.sentiment = self.get_sentiment()
        except ValueError:
            # Handle the case where score is not a number
            self.score = None
            self.sentiment = None
    

    
        
    def get_sentiment(self):
        if self.score <= 2:
            return Sentiment.NEGATIVE
        elif self.score == 3:
            return Sentiment.NEUTRAL
        else: # Amazon review is a 4 or 5
            return Sentiment.POSITIVE
        
class ReviewContainer:
    def __init__(self, reviews):
        self.reviews = reviews
    
    def get_text(self):
        return [x.text for x in self.reviews]
    
    def get_x(self, vectorizer):
        return vectorizer.transform(self.get_text())
    
    def get_y(self):
        return [x.sentiment for x in self.reviews]
    
    def get_category(self):
        return [x.category for x in self.reviews]
    
    def evenly_distribute(self):
        negative = list(filter(lambda x: x.sentiment == Sentiment.NEGATIVE, self.reviews))
        positive = list(filter(lambda x: x.sentiment == Sentiment.POSITIVE, self.reviews))
        positive_shrunk = positive[:len(negative)]
        print(len(positive_shrunk))
        self.reviews = negative + positive_shrunk
        random.shuffle(self.reviews)
        print(self.reviews[0])

# %%
file_names = ['Electronics_small.json', 'Books_small.json', 'Clothing_small.json', 'Grocery_small.json', 'Patio_small.json']
file_categories = [Category.ELECTRONICS, Category.BOOKS, Category.CLOTHING, Category.GROCERY, Category.PATIO]

reviews = []
for i in range(len(file_names)):
    file_name = file_names[i]
    category = file_categories[i]
    with open(file_name) as f:
        for line in f:
            review_json = json.loads(line)
            review = Review(category, review_json['reviewText'], review_json['overall'])
            reviews.append(review)

# %%
train, test = train_test_split(reviews, test_size = 0.33, random_state=42)

train_container = ReviewContainer(train)
#train_container.evenly_distribute()
test_container = ReviewContainer(test)
#test_container.evenly_distribute()

corpus = train_container.get_text()
# vectorizer = CountVectorizer(binary=True)
# vectorizer.fit(corpus)
vectorizer = TfidfVectorizer()
vectorizer.fit(corpus)

train_x = train_container.get_x(vectorizer)
train_y = train_container.get_category()

test_x = test_container.get_x(vectorizer)
test_y = test_container.get_category()

# %%
from sklearn import svm

clf = svm.SVC(C=16, kernel='linear', gamma='auto')
clf.fit(train_x, train_y)
# Out:
# SVC(C=16, gamma='auto', kernel='linear')

# %%
test_set = ['great for my wedding', 'loved it in my garden', 'good computer']
new_test = vectorizer.transform(test_set)

clf.predict(new_test)
# Out:
# array([5., 5., 5.])

# %%
import random

class Category:
    ELECTRONICS = "ELECTRONICS"
    BOOKS = "BOOKS"
    CLOTHING = "CLOTHING"
    GROCERY = "GROCERY"
    PATIO = "PATIO"
    
    
class Sentiment:
    NEGATIVE ='NEGATIVE'
    NEUTRAL = 'NEUTRAL'
    POSITIVE = 'POSITIVE'
class Review:
    def __init__(self, text, score, category):
        self.text = text
        self.category = category
        
        # Try to convert score to an integer, otherwise assign None
        try:
            self.score = int(score)
        except ValueError:
            self.score = None
        
        self.sentiment = self.get_sentiment()

    def get_sentiment(self):
        if self.score is None:
            return None  # Cannot determine sentiment without a valid score
        elif self.score <= 2:
            return Sentiment.NEGATIVE
        elif self.score == 3:
            return Sentiment.NEUTRAL
        else:
            return Sentiment.POSITIVE


class ReviewContainer:
    def __init__(self, reviews):
        self.reviews = reviews
    
    def get_text(self):
        return [x.text for x in self.reviews]
    
    def get_x(self, vectorizer):
        return vectorizer.transform(self.get_text())
    
    def get_y(self):
        return [x.sentiment for x in self.reviews]
    
    def get_category(self):
        return [x.category for x in self.reviews]
    
    def evenly_distribute(self):
        negative = list(filter(lambda x: x.sentiment == Sentiment.NEGATIVE, self.reviews))
        positive = list(filter(lambda x: x.sentiment == Sentiment.POSITIVE, self.reviews))
        positive_shrunk = positive[:len(negative)]
        print(len(positive_shrunk))
        self.reviews = negative + positive_shrunk
        random.shuffle(self.reviews)
        print(self.reviews[0])

# %% [markdown]
# Data prep

# %% [markdown]
# classification

# %%
from sklearn import svm

clf = svm.SVC(C=16, kernel='linear', gamma='auto')
clf.fit(train_x, train_y)
# Out:
# SVC(C=16, gamma='auto', kernel='linear')

# %%
test_set = ['great for my wedding', 'loved it in my garden', 'good computer']
new_test = vectorizer.transform(test_set)

clf.predict(new_test)
# Out:
# array([5., 5., 5.])

# %%
import numpy as np

# Convert the dense matrix to numpy array before passing to the classifier
gnb = GaussianNB()

# Fit the model with the converted arrays
gnb.fit(np.asarray(train_x.todense()), train_y)

# Test the model with the converted arrays
gnb.score(np.asarray(test_x.todense()), test_y)
# Out:
# 0.5806060606060606
